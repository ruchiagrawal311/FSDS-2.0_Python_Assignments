# %% [markdown]
# # Q 1. Add the current date to the text file today.txt as a string.

# %%
# ANS 
import datetime
file= open("today.txt","w")
file.write(datetime.datetime.now().strftime("%d-%m-%y"))
file.close()
    
file=open("today.txt","r") 
print(file.read())
file.close()
# Out:
# 12-07-23

# %% [markdown]
# # Q 2. Read the text file today.txt into the string today_string

# %%
# ANS 
file = open("today.txt","r")
today_string = file.read()
print(today_string)
# Out:
# 12-07-23

# %% [markdown]
# # Q 3. Parse the date from today_string.

# %%
# ANS 
from datetime import datetime
file = open("today.txt","r")
parsed_date = datetime.strptime(today_string,'%d-%m-%y')
print(parsed_date)
# Out:
# 2023-07-12 00:00:00

# %% [markdown]
# # Q 4. List the files in your current directory

# %%
# ANS 
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# 1. Keynes, 1937.pdf
# 1.pdf
# 10.1002@pa.2113.pdf
# 1171219.pdf
# 12227662556.pdf
# 1603.02754.pdf
# 1628234791brief.pdf
# 1673805220.doc
# 2. Kalecki - The Principle of Increasing Risk, 1937 (1).pdf
# 2. Kalecki - The Principle of Increasing Risk, 1937.pdf
# 2015 rbi.pdf
# 2022_Revised_nternational_economics.docx
# 232-4.pdf
# 2nd.pdf
# 3.pdf
# 4. Kaldor, 1986 - The Scourge of Monetarism.pdf
# 4.HANDLOOM+industry+in+india.pdf
# 4th.pdf
# 6.pdf
# Abstract1.docx
# administrator,+jcim11_2art03.pdf
# AdmitCard-220510339376.pdf
# Agricultural Trends in India, 1891-1947_ Output, Availability, and Productivity ( PDFDrive ).pdf
# AIFTA.pptx
# Albrecht & Smith.pdf
# Amit Bhaduri - The Dynamics of Commodity Production.pdf
# Anaconda3-2022.10-Windows-x86_64.exe
# Annual_Report_PLFS_2019_20m1627036454797.pdf
# Application.pdf
# application_log.txt
# ASEAN.docx
# Assignment_1.docx
# BCCCO_2023_2030007.pdf
# BICCO_2023_1839779 (1).pdf
# BICCO_2023_1839779.pdf
# Bipan Chandra - The Rise and Growth of Economic Nationalism (2010) (1).pdf
# Blank-converted.docx
# Blank.pdf
# BOBCCO_2023_215634.pdf
# BOBCSDO_2022_36157_page-0001.jpg
# books.csv
# books.db
# BRCCO_2023_2790525.pdf
# Can Central Bank Reduce Inflation-.pdf
# Capital-Volume-I.pdf
# Carl Popper- The Logic of Scientific Discovery.pdf
# caste.xlsx
# Category-WPS Office (1).docx
# Category-WPS Office.docx
# CI 520- Mid Sem-Term Paper.docx
# CI 520_MID TERM_RUCHI.pdf
# ConfirmationPage-230510663073.pdf
# Copy of Shreeva logo landscape.PNG
# Copy of Shreeva logo landscape.PNG (1).png
# Copy of Shreeva logo landscape.PNG.png
# Cover_Letter.pdf
# CV_Ruchi.pdf
# Data Science.docx
# DeGroot Schervish Probability and Statistics 4ed.pdf
# depr_2016.pdf
# desktop.ini
# DL01633169_22J.pdf
# DS Workbook.pdf
# DSa Mock Test.ipynb
# DSC_0182.JPG
# DSE Probability Ques Set.pdf
# EC IT.pdf
# Econometric Analysis of Cross Section and Panel Data by Jeffrey M. Wooldridge (z-lib.org).pdf
# Electric_Vehicle_Population_Data.csv
# EmeraldInsight_citations_20230513091859.ris
# End sem.pdf
# EndSem_2020.pdf
# Python Basic Assignment  21.ipynb
# Python Basic Assignment  23.ipynb
# Python Basic Assignment  25.ipynb
# Python Basic Assignment 1.ipynb
# Python Basic Assignment 10.ipynb
# Python Basic Assignment 11.ipynb
# Python Basic Assignment 12.ipynb
# Python Basic Assignment 13.ipynb
# Python Basic Assignment 14.ipynb
# Python Basic Assignment 15.ipynb
# Python Basic Assignment 16.ipynb
# Python Basic Assignment 17.ipynb
# Python Basic Assignment 18.ipynb
# Python Basic Assignment 19.ipynb
# Python Basic Assignment 2.ipynb
# Python Basic Assignment 20.ipynb
# Python Basic Assignment 22.ipynb
# Python Basic Assignment 24.ipynb
# Python Basic Assignment 3.ipynb
# Python Basic Assignment 4.ipynb
# Python Basic Assignment 5.ipynb
# Python Basic Assignment 6.ipynb
# Python Basic Assignment 7.ipynb
# Python Basic Assignment 8.ipynb
# Python Basic Assignment 9 .ipynb
# QT Sure Shots.pdf
# RBI Data.xlsx
# rbi grade b call letter.pdf
# rbi-grade-b-2019.pdf
# Readings-Wk-4-Amartya-Sen-Poverty-as-Capability-Deprivation-from-Development-as-Freedom.pdf
# Reasoning Shortcut Tricks.pdf
# ReasoningPuzzlesk2opt.pdf
# Reassessing the Impact of the ASEAN.docx
# redis-stable.tar.gz
# REGRESSION ANALYSIS-converted.docx
# Relevance of Comparative Advantage.docx
# Research-Assistant-Cover-Letter-Example-Free-Download.zip
# Return Sum As a Linked List.ipynb
# Richard T. Froyen Macroeconomics Theories ( PDFDrive ).pdf
# Rohatgi - An Introduction To Probability and Statistics.pdf
# Ruchi kumari_200810164563.pdf
# RUCHI KUMARI_BOOK REVIEW (1).pdf
# Ruchi_200810164563.pdf
# Ruchi_EndSeM_EP521.pdf
# Ruchi_EndTerm_EP531.pdf
# RUCHI_KUMARI_CV (1).pdf
# Ruchi_Kumari_Resume_16-05-2023-19-38-38.pdf
# Ruchi_Resume.pdf
# Ruchi_Seminar_Paper_EP516.pdf
# SAURAV_KUMAR_CV.pdf
# sebi_2021.pdf
# sebi_2022.pdf
# sec d.docx
# SECTORAL ANALYSIS (1).docx
# SECTORAL ANALYSIS.docx
# Share+SUSHMA+KAMDI+pdf.docx
# Shivanuprav_TermPaper_International Trade (1).docx
# Simon & Blume.pdf
# Social science project (full) (1).pdf
# Social science project (full).pdf
# State-Bank-of-Travancore-2015.pdf
# Surajit.docx
# T1NVcHpndUxycGVvYmVkTTliWVIzUT09.pdf
# TEA PLANTATION IN COLONIAL INDIA.docx
# Template 2.docx
# test.txt
# The era from 1950.docx
# The Tragedy of Commons.pdf
# The-Hindu-Review-December-2021.pdf
# The_Balance_Letter_2062548_2022.docx
# third.pdf
# Today's Discussion 06-10-2022.docx
# today.txt
# university_records.csv
# video.mp4
# VSCodeUserSetup-x64-1.74.1.exe
# Weighted_Average_Lending_Rate_for_SCBs_based_on_BSR-1A_Data_on_Borrowal_Accounts.xlsx
# Whatever happened to Employment India’s recent record from a nationally representative sample.pdf
# WhatsApp Image 2020-03-16 at 10.38.13 AM (2).jpeg
# WhatsApp Image 2020-03-16 at 10.38.14 AM (1).jpeg
# WhatsApp Image 2020-03-16 at 10.38.14 AM (2).jpeg
# 24 Pricing and Output Decisions in Different Market Structures (Part 2) - Monopoly LR Equilbrium, Multiplant Monopolist, Lerner'.mp4
# 24 Pricing in Different Market Structures (Part 3) - Monopolist will never operate on Inealstic Portion of demand curve (IES 201.mp4
# 26 Pricing in Different Market Structures (Part 4) - First, Second and Third Degree Price Discrimination.mp4
# 10. Green Climate Fund .mp4.mp4
# 11. Carbon Markets .mp4.mp4
# 6 UNFCCC United Nations Framework Convention on Climate Change.mp4
# 7 Bali Action Plan.mp4
# 9 Green Finance Climate Finance.mp4
# 1. Import Substitution - Part 1 -.mp4.mp4
# 14. Types of Deficit - Revenue Expenditure - Capital Expenditure - Revure Receipts - Capital Receipts - .mp4.mp4
# 2. Import Substitution - Part 2 -.mp4.mp4
# 3. Planning in Pre Reform and Post Reform Era - Part 1 -.mp4.mp4
# 4. Planning in Pre and Post Reform Era - Changing Role of State - Self Reliance is a myth - Part 2 -.mp4.mp4
# 5. Planning in Pre and Post Reform Era - Part 3 - What led to Crises and Shift in Planning Strategy - .mp4.mp4
# 6. Planning in Pre and Post Reforms Era - Part 4 - Failures of Reforms -.mp4.mp4
# 11-. Translog Production Function - Monotonicity - Marginal Product - MRTS - Elasticity of Substitution -.mp4.mp4
# 12. Translog Cost Function - Elasticity of Substitution -.mp4.mp4
# 13-. Constant Cost - Decreasing Cost - Increasing Cost Industry - IES 2015 - Simple Numerical Question -.mp4.mp4
# 14-. Incidence of Tax - Numerical Question - IES 2015 -.mp4.mp4
# 15.- External Economies and Diseconomies - LR Supply function - IES 2016 -.mp4.mp4
# 16-. Profit Maximization (IES 2017) - CES Production function with DRS and CRS (IES 2014) - AP and MP (IES 2018) -.mp4.mp4
# 17 Cost Minimization, Example of Cost functions (IES 2020), Properties of Cost function, Returns to Scale (IES 2018).mp4
# 18 Cost function and Duality (IES 2019), U-shaped AC curve (IES 2010), Derivation of LTC, LAC and LMC curves.mp4
# 19 Measures of Efficiency - Technical Efficiency, Allocative Efficiency, Productive Efficiency, X Efficiency.mp4
# 22 Equilibrium of the Firm and Industry (Part 3)- Tax Incidence Analysis.mp4
# 52 Markets Part 1 Perfect Competition Demand Curve Supply Curve Shut Down Point SR Supply Curve SR and LR Equilibrium.mp4
# 100 Solutions to Externalities.mp4
# 101 Local and Global Public Goods.mp4
# 102 Tiebout Model and Local Public Goods.mp4
# 103Social Choice Theory and Arrow Impossibility Theorem.mp4
# 104 Allocation of Resources of Public Goods and Government Failure.mp4
# 106 Incidence of Taxation.mp4
# 11optimal taxation part 1.mp4
# 13 optimal taxation part 2 (ies).mp4
# 96 Introduction to Public Economics, Welfare Functions, Application of Welfare criteron in Welfare Economics.mp4
# 97 Externalities.mp4
# 98 Optimal Provison of Public Goods.mp4
# 99 Classification of Public Goods.mp4
# 1. Measures of Central Tendency - Arithmetic Mean of Ungrouped Data -.mp4.mp4
# 2. Measures of Central Tendency - Median and Mode of Ungrouped Data -.mp4.mp4
# 3. Measures of Central Tendency - Geometric and Harmonic Mean -.mp4.mp4
# 47. Determination of Output - Division of Output - Determinants of Demand of National Output -.mp4.mp4
# 48. Equilbrium Rate of Interest - Demand and Supply of Loanable Funds -.mp4.mp4
# 61 GDP, Its Components, Multiplier, Balanced Budget Multiplier.mp4
# 621 H theory of Money Supply.mp4
# 63 The Classical and Neo Classical Theory of Money (Quantity Theory of Money).mp4
# 64 The Classical Theory of Interest Rate.mp4
# 65 The Keynesian Theory of Demand for Money and Interest Rate.mp4
# zoo.cpython-39.pyc

# %% [markdown]
# # Q 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
# ANS .
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1. Keynes, 1937.pdf',
#  '1.pdf',
#  '10.1002@pa.2113.pdf',
#  '1171219.pdf',
#  '12227662556.pdf',
#  '1603.02754.pdf',
#  '1628234791brief.pdf',
#  '1673805220.doc',
#  '2. Kalecki - The Principle of Increasing Risk, 1937 (1).pdf',
#  '2. Kalecki - The Principle of Increasing Risk, 1937.pdf',
#  '2015 rbi.pdf',
#  '2022_Revised_nternational_economics.docx',
#  '232-4.pdf',
#  '2nd.pdf',
#  '3.pdf',
#  '4. Kaldor, 1986 - The Scourge of Monetarism.pdf',
#  '4.HANDLOOM+industry+in+india.pdf',
#  '4th.pdf',
#  '6.pdf',
#  'Abstract1.docx',
#  'administrator,+jcim11_2art03.pdf',
#  'AdmitCard-220510339376.pdf',
#  'Agricultural Trends in India, 1891-1947_ Output, Availability, and Productivity ( PDFDrive ).pdf',
#  'AIFTA.pptx',
#  'Albrecht & Smith.pdf',
#  'Amit Bhaduri - The Dynamics of Commodity Production.pdf',
#  'Anaconda3-2022.10-Windows-x86_64.exe',
#  'Annual_Report_PLFS_2019_20m1627036454797.pdf',
#  'Application.pdf',
#  'application_log.txt',
#  'ASEAN.docx',
#  'Assignment_1.docx',
#  'BCCCO_2023_2030007.pdf',
#  'BICCO_2023_1839779 (1).pdf',
#  'BICCO_2023_1839779.pdf',
#  'Bipan Chandra - The Rise and Growth of Economic Nationalism (2010) (1).pdf',
#  'Blank-converted.docx',
#  'Blank.pdf',
#  'BOBCCO_2023_215634.pdf',
#  'BOBCSDO_2022_36157_page-0001.jpg',
#  'books.csv',
#  'books.db',
#  'BRCCO_2023_2790525.pdf',
#  'Can Central Bank Reduce Inflation-.pdf',
#  'Capital-Volume-I.pdf',
#  'Carl Popper- The Logic of Scientific Discovery.pdf',
#  'caste.xlsx',
#  'Category-WPS Office (1).docx',
#  'Category-WPS Office.docx',
#  'CI 520- Mid Sem-Term Paper.docx',
#  'CI 520_MID TERM_RUCHI.pdf',
#  'Compressed',
#  'ConfirmationPage-230510663073.pdf',
#  'Copy of Shreeva logo landscape.PNG',
#  'Copy of Shreeva logo landscape.PNG (1).png',
#  'Copy of Shreeva logo landscape.PNG.png',
#  'Cover_Letter.pdf',
#  'CV_Ruchi.pdf',
#  'Data Science.docx',
#  'DeGroot Schervish Probability and Statistics 4ed.pdf',
#  'depr_2016.pdf',
#  'desktop.ini',
#  'DL01633169_22J.pdf',
#  'Documents',
#  'DS Workbook.pdf',
#  'DSa Mock Test.ipynb',
#  'DSC_0182.JPG',
#  'DSE Probability Ques Set.pdf',
#  'EC IT.pdf',
#  'Econometric Analysis of Cross Section and Panel Data by Jeffrey M. Wooldridge (z-lib.org).pdf',
#  'Electric_Vehicle_Population_Data.csv',
#  'EmeraldInsight_citations_20230513091859.ris',
#  'End sem.pdf',
#  'EndSem_2020.pdf',
#  'EnviStats-India2018.pdf',
#  'EP521_RUCHI_MIDTERM.pdf',
#  'Exchange rate determination.docx',
#  'Experimental Economics End Term 1.pdf',
#  'Experimental Economics Midterm-converted.docx',
#  'Experimental Economics Midterm...pdf',
#  'Experimental Economics Midterm.pdf',
#  'Experimental Economics Midtermm.pdf',
#  'Experimental End Sem.docx',
#  'FD & LF_EPW.pdf',
#  'Fish Products.docx',
#  'FREIT507.pdf',
#  'Friedman on QTM.pdf',
#  'fulltext_stamped.pdf',
#  'Gen. Theory Introduction by RN Ghosh.pdf',
#  'Git-2.39.0-64-bit.exe',
#  'Growth and Development.pdf',
#  'Hal R. Varian - Microeconomics analysis.pdf',
#  'handloom industry.pdf',
#  'handloom.pdf',
#  'HARSH (Roll no. 19) (1).ods',
#  'HARSH (Roll no. 19).ods',
#  'hello.docx',
#  'HickandBurchardt.CapabilityDeprivation_OA.pdf',
#  'Hyman Minsky_John Maynard Keynes.pdf',
#  'HYPOTHESIS 1.0.docx',
#  'IBALauncher.exe',
#  'IDM.Trial.Reset.v1.0.0.zip',
#  'idman641build8.exe',
#  'ies application.pdf',
#  'ies part 1.pdf',
#  'IJTRD20776.doc',
#  'IMG-20190803-WA0000.jpg',
#  'Indias_Labour_Market_during_the_2000s_Jayan J Thomas.pdf',
#  'Ineuron',
#  'ing_Poverty_as_Multidimensional_Approach_in_context_to_India.txt.pdf',
#  'Internship opportunity- Ministry of Women & Child Dev, GOI.docx',
#  'Introduction to Logic - P. Suppes (1957) WW.pdf',
#  'jeko_482-9.pdf',
#  'JNU-PhD-CESP-Economics-2019.pdf',
#  'JNUEE-PhD-Regional-Development-Economics-ECNH-2020.pdf',
#  'kaldor-how-monetarism-failed (1).pdf',
#  'kaldor-how-monetarism-failed.pdf',
#  'Keynes_General Theory.pdf',
#  'KPMG_VI_New_raw_data_update_final.xlsx',
#  'Krishna Bhardwaj, 1978, R.C. Dutt Lectures.pdf',
#  'Labor_Economics_George_J_borjas.pdf',
#  'Lance Taylor_Structuralist Macroecnomics Applicable Models for the Third World.pdf',
#  'Literature review (1).docx',
#  'Literature review_Final.docx',
#  'Macroeconomics of Fiscal Policy.pdf',
#  'Macroeconomics-6th-Edition-Blanchard.pdf',
#  'mas coell.pdf',
#  'Masters.pdf',
#  'MB_LIII_13_310318_Surajit_Das.pdf',
#  'Mercantilism.pdf',
#  'Michal Kalecki - Selected Essays...(1971).pdf',
#  'Microeconomic Theory_ Basic Principles and Extensions ( PDFDrive ).pdf',
#  'Midterm.pdf',
#  'MME_After-Midsem.pdf',
#  'MNCs and their host countries have always a suppor.docx',
#  'MPRA_paper_108575.docx',
#  'Music',
#  'my thesis.docx',
#  'mydocument.docx',
#  'National Income Aggregates.pptx',
#  'New Doc 2019-11-08 12.35.03.pdf',
#  'Notifi_IES_2020_Eng.pdf',
#  'null.docx',
#  'paper-2-notes indian eco.pdf',
#  'peak demand and consumption (1).xls',
#  'peak demand and consumption.xls',
#  'PGA 3.0 Schedule-WD (1).xlsx',
#  'POA Jul OCR.pdf',
#  'Political-science-6-12-eb4bdd (1).pdf',
#  'Political-science-6-12-eb4bdd.pdf',
#  'POVERTY AND CAPABILITY APPROACH.docx',
#  'Poverty as Capability Deprivation_Rod Hick_15th_0.pdf',
#  'Poverty is a relationship between the essential ne (1).docx',
#  'Poverty is a relationship between the essential ne.docx',
#  'Poverty_as_capability_deprivation(A.K.Sahu).pdf',
#  'Prabhat Patnaik_The Value of Money (1).pdf',
#  'Prabhat Patnaik_The Value of Money.pdf',
#  'Presentation.pptx',
#  'Presentation1.pptx',
#  'Programs',
#  'Proposal.pdf',
#  'Python Basic  Progrmming Assignment 9.ipynb',
#  'Python Basic Assignment  21.ipynb',
#  'Python Basic Assignment  23.ipynb',
#  'Python Basic Assignment  25.ipynb',
#  'Python Basic Assignment 1.ipynb',
#  'Python Basic Assignment 10.ipynb',
#  'Python Basic Assignment 11.ipynb',
#  'Python Basic Assignment 12.ipynb',
#  'Python Basic Assignment 13.ipynb',
#  'Python Basic Assignment 14.ipynb',
#  'Python Basic Assignment 15.ipynb',
#  'Python Basic Assignment 16.ipynb',
#  'Python Basic Assignment 17.ipynb',
#  'Python Basic Assignment 18.ipynb',
#  'Python Basic Assignment 19.ipynb',
#  'Python Basic Assignment 2.ipynb',
#  'Python Basic Assignment 20.ipynb',
#  'Python Basic Assignment 22.ipynb',
#  'Python Basic Assignment 24.ipynb',
#  'Python Basic Assignment 3.ipynb',
#  'Python Basic Assignment 4.ipynb',
#  'Python Basic Assignment 5.ipynb',
#  'Python Basic Assignment 6.ipynb',
#  'Python Basic Assignment 7.ipynb',
#  'Python Basic Assignment 8.ipynb',
#  'Python Basic Assignment 9 .ipynb',
#  'QT Sure Shots.pdf',
#  'RBI Data.xlsx',
#  'rbi grade b call letter.pdf',
#  'rbi-grade-b-2019.pdf',
#  'Readings-Wk-4-Amartya-Sen-Poverty-as-Capability-Deprivation-from-Development-as-Freedom.pdf',
#  'Reasoning Shortcut Tricks.pdf',
#  'ReasoningPuzzlesk2opt.pdf',
#  'Reassessing the Impact of the ASEAN.docx',
#  'redis-stable.tar.gz',
#  'Registration',
#  'REGRESSION ANALYSIS-converted.docx',
#  'Relevance of Comparative Advantage.docx',
#  'Research-Assistant-Cover-Letter-Example-Free-Download.zip',
#  'Return Sum As a Linked List.ipynb',
#  'Richard T. Froyen Macroeconomics Theories ( PDFDrive ).pdf',
#  'Rohatgi - An Introduction To Probability and Statistics.pdf',
#  'Ruchi kumari_200810164563.pdf',
#  'RUCHI KUMARI_BOOK REVIEW (1).pdf',
#  'Ruchi_200810164563.pdf',
#  'Ruchi_EndSeM_EP521.pdf',
#  'Ruchi_EndTerm_EP531.pdf',
#  'RUCHI_KUMARI_CV (1).pdf',
#  'Ruchi_Kumari_Resume_16-05-2023-19-38-38.pdf',
#  'Ruchi_Resume.pdf',
#  'Ruchi_Seminar_Paper_EP516.pdf',
#  'SAURAV_KUMAR_CV.pdf',
#  'sebi_2021.pdf',
#  'sebi_2022.pdf',
#  'sec d.docx',
#  'SECTORAL ANALYSIS (1).docx',
#  'SECTORAL ANALYSIS.docx',
#  'Semester 4 graduation',
#  'Share+SUSHMA+KAMDI+pdf.docx',
#  'Shivanuprav_TermPaper_International Trade (1).docx',
#  'Simon & Blume.pdf',
#  'Social science project (full) (1).pdf',
#  'Social science project (full).pdf',
#  'State-Bank-of-Travancore-2015.pdf',
#  'Stats',
#  'Surajit.docx',
#  'T1NVcHpndUxycGVvYmVkTTliWVIzUT09.pdf',
#  'TEA PLANTATION IN COLONIAL INDIA.docx',
#  'Template 2.docx',
#  'test.txt',
#  'The era from 1950.docx',
#  'The Tragedy of Commons.pdf',
#  'The-Hindu-Review-December-2021.pdf',
#  'The_Balance_Letter_2062548_2022.docx',
#  'third.pdf',
#  "Today's Discussion 06-10-2022.docx",
#  'today.txt',
#  'university_records.csv',
#  'Video',
#  'video.mp4',
#  'VSCodeUserSetup-x64-1.74.1.exe',
#  'Weighted_Average_Lending_Rate_for_SCBs_based_on_BSR-1A_Data_on_Borrowal_Accounts.xlsx',
#  'Whatever happened to Employment India’s recent record from a nationally representative sample.pdf',
#  'WhatsApp Image 2020-03-16 at 10.38.13 AM (2).jpeg',
#  'WhatsApp Image 2020-03-16 at 10.38.14 AM (1).jpeg',
#  'WhatsApp Image 2020-03-16 at 10.38.14 AM (2).jpeg',
#  'WhatsApp Image 2020-03-16 at 10.38.14 AM.jpeg',
#  'WhatsApp Image 2020-03-16 at 10.38.15 AM (1).jpeg',
#  'WhatsApp Image 2020-03-16 at 10.38.15 AM.jpeg',
#  'WhatsApp Image 2020-03-16 at 10.38.16 AM.jpeg',
#  'WhatsApp Image 2021-12-15 at 10.19.37 AM.jpeg',
#  'WhatsApp Image 2021-12-15 at 9.09.14 PM.jpeg',
#  'WhatsApp Image 2021-12-15 at 9.09.25 PM.jpeg',
#  'WhatsApp Image 2023-01-07 at 17.32.59.jpeg',
#  'WhatsApp Image 2023-01-15 at 23.10.05.docx',
#  'WhatsApp Image 2023-01-15 at 23.10.05.jpeg',
#  'WhatsApp Image 2023-01-15 at 23.15.24 (1).docx',
#  'WhatsApp Image 2023-01-15 at 23.15.24.doc',
#  'WhatsApp Image 2023-01-15 at 23.15.24.docx',
#  'WhatsApp Image 2023-01-15 at 23.15.24.jpeg',
#  'WhatsApp Image 2023-01-15 at 23.15.24.pdf',
#  'WhatsApp-Image-2023-01-15-at-23.15.24.doc',
#  'WILLIAM DARITY JR A model of original sin.pdf',
#  'WP_2018_225.pdf',
#  'zoo.ipynb',
#  'zoo.py',
#  'Zoom_cm_fo42mnktZ9vvrZo4_mcip3Hd9ZWyTPxRaySn79z-n+9O76IACchnPL@ocdpOIFLRonMFFpw_kcd701bf207ba818a_.exe',
#  '[Kaldor,_Nicholas]_The_Scourge_of_Monetarism.pdf',
#  '__pycache__',
#  '~$AIFTA.pptx',
#  '~$RBI Data.xlsx',
#  '~WRL0633.tmp',
#  '~WRL1575.tmp']

# %% [markdown]
# # Q 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
#ANS
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %% [markdown]
# # Q 7. Create a date object of your day of birth.

# %%
from datetime import datetime
dob = datetime.strptime("30/10/1999","%d/%m/%Y")
print(dob,type(dob))
# Out:
# 1999-10-30 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# # Q 8. What day of the week was your day of birth?

# %%
# ANS 
from datetime import datetime
dob = datetime(1999,10,30)
print(dob.strftime("%A"))
# Out:
# Saturday

# %% [markdown]
# # Q 9. When will you be (or when were you) 10,000 days old?

# %%
# ANS 9.
from datetime import datetime, timedelta
my_dob = datetime.strptime("30/10/1999",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1972, 6, 13, 0, 0)
